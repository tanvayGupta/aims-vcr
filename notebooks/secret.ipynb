# %% [markdown]
# ### No API keys over here lol

# %% [markdown]
# So here are the baseline stats
# Using Qwen 3 4B Instruct
#
# ## Qwen-3 Non-finetuned
#
# | Metric | Accuracy |
# |--------|----------|
# | Q -> A | 58% |
# | Q -> R | 32% |
# | Q -> AR | 18% |
#
# ## Qwen-3 Finetuned v1
#
# Trained SFT
#
# Q->A 150 rows and
#
# QA -> R 150 rows
#
# | Metric | Accuracy | Improvement (wrt Baseline) |
# |--------|----------|----------------------------|
# | Q -> A | 63.3% | 9% |
# | Q -> R | 13.3% | -75% |
# | Q -> AR | 6.6% | -63% |
#
# Now notice how Q -> A improved, not Q -> AR
#
#
# ## Qwen-3 Finetuned v2
#
# Trained SFT
#
# Q->A 150 rows + 100 rows = 250 rows
#
# QA -> R 150 rows + 100 rows = 250 rows
#
# Q -> AR 100 rows
#
# | Metric | Accuracy | Improvement (wrt Baseline) |
# |--------|----------|----------------------------|
# | Q -> A | 66.6% | 14%% |
# | Q -> R | 43.3% | 35% |
# | Q -> AR | 30% | 66% |
#
# WOOHOOO, now its somewhere near what I want. So training is the key na, I got it now
